# %% [markdown]
# <table align="center" width="100%">
#             <div align="center">
#                 <font color="cyan" size="6">
#                     <b>🍿 Netflix Data Cleaning 🥤</b>
#                 </font>

# %% [markdown]
# <b><font color="white"><h3>🔹 Importing essential libraries for data analysis and visualization:</b></font>

# %% [markdown]
# 1. NumPy `(import numpy as np)`
#
# **Purpose:**
#
# Numerical Python — high-performance library for numerical operations, especially with arrays.
#
# **Use Cases:**
#
# - Multi-dimensional arrays (ndarray)
#
# - Mathematical functions: mean, median, std, etc.
#
# - Fast operations over arrays/matrices
#
# 2. Pandas `(import pandas as pd)`
#
# **Purpose:**
#
# Data manipulation and analysis library — best for working with tabular data like Excel, CSV, SQL tables.
#
# **Use Cases:**
#
# - Read/write data (CSV, Excel, etc.)
#
# - DataFrames and Series for tabular and 1D data
#
# - Grouping, filtering, cleaning, and reshaping data
#
# 3. files from Google Colab `(from google.colab import files)`
#
# **Purpose:**
#
# Special module in Google Colab to handle file uploads and downloads.
#
# **Use Cases:**
#
# - Uploading files from your local system to Colab
#
# - Downloading processed files back to your computer

# %%
import numpy as np
import pandas as pd
from google.colab import files

# %% [markdown]
# <b><font color="white"><h2>🔍 Loading the Netflix dataset into a DataFrame:</b></font>

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9f8ec807-fd9d-47ab-8701-c1d8850ea1ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f8ec807-fd9d-47ab-8701-c1d8850ea1ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("netflix.csv")

# %% [markdown]
# <b><font color="white"><h2>🔍 Displaying the first 5 rows of the DataFrame to preview the data:</b></font>

# %%
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# <b><font color="white"><h3>🔍 Drop Description Column:</b></font>

# %%
df = df.drop('description', axis=1)

# %% [markdown]
# ### <b><font color="white"><h1>📊 Summary of the Netflix Dataset</b></font>

# %% [markdown]
# This dataset offers a comprehensive overview of movies and TV shows available on Netflix. Each row corresponds to a unique title and includes several important attributes:
#
# - **🎬 Show ID**: A unique identifier for each title.
# - **📺 Type**: Specifies whether the content is a *Movie* or a *TV Show*.
# - **📝 Title**: Contains the main title, sometimes including subtitles.
# - **🎬 Director**: May include multiple directors listed in a single cell.
# - **⭐ Cast**: Lists one or more cast members associated with the title.
# - **🌍 Country**: Indicates the country or countries where the title was produced; joint productions are common.
# - **📅 Date Added & Release Year**: Show when the title was added to Netflix and its original release year.
# - **🔞 Rating**: Reflects the target audience (e.g., TV-MA, PG, R).
# - **⏱️ Duration**: Specifies runtime in minutes for movies or number of seasons for TV shows.
# - **🎭 Genre (listed_in)**: Classifies titles into genres such as *Drama*, *Comedy*, *Action*, *Thriller*, *Documentary*, etc.
#
# 📆 **Time Span**: The dataset includes titles released between **1992 and 2021**, capturing the diversity and evolution of Netflix's global content library.
#
# 👉 **In summary**, this dataset enables a wide range of analytical opportunities focused on:
# - Content type
# - Genre
# - Regional distribution
# - Duration
# - Audience suitability

# %% [markdown]
# ### <b><font color="white"><h1>📝 Columns Descriptions:</b></font>

# %% [markdown]
# - **📺 Type**: Indicates whether the entry is a *Movie* or a *TV Show*.
# - **🎞️ Title**: The title of the movie or TV show.
# - **🎬 Director/Creator**: The name of the director for movies or the creator for TV shows.
# - **🌍 Country**: The country of origin where the movie or TV show was produced.
# - **📅 Release Date**: The date when the movie or TV show was released on Netflix.
# - **📆 Release Year**: The year when the movie or TV show was originally released.
# - **🔞 Rating**: The content rating assigned to the movie or TV show, indicating its suitability for different age groups. Ratings include:
#   *TV-MA, TV-14, R, PG-13, TV-PG, TV-Y, PG, TV-G, TV-Y7*.
# - **⏱️ Duration**: The duration of the movie or TV show.
#   - For movies: Given in minutes
#   - For TV shows: Indicates the number of seasons
# - **🎭 Genres**: The genres or categories the movie or show belongs to, such as *Drama, Comedy, Action, Thriller*, etc.

# %% [markdown]
# <b><font color="white"><h2>🔍 Displaying basic information about the DataFrame:</b></font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 757.0+ KB

# %% [markdown]
# ### <b><font color="white"><h2>🔍 Issues with the Netflix Dataset:</b></font>

# %% [markdown]
# ## 🧼 1. **Dirty Data**
#
# Dirty data refers to inaccurate, incomplete, or duplicate entries that reduce the reliability of analysis.
#
# ### 📌 Column: `show_id`
#
# - **Completeness Issue**
#   Duplicate entries found in rows `'s304'`, `'s3372'`, `'s760'`, `'s4523'`, and `'s3963'` indicating redundancy of titles.
#
# - **Quality Issue**
#   Show IDs like `'s1'`, `'s2'`, `'s3'`, `'s4'`, and `'s5'` are used for repeated content, showing **redundant and inconsistent identifiers**.
#
# - **Analytical Relevance**
#   `show_id` is a **unique identifier** that holds no analytical meaning and can be **excluded from modeling or visualization**.
#
# ---
#
# ### 📌 Column: `type`
#
# - **Consistency Issue**
#   Stored as an **object** data type instead of a **categorical** type, which would be more efficient for repeated values like "Movie" and "TV Show".
#
# ---
#
# ### 📌 Column: `date_added`
#
# - **Validity Issue**
#   Stored as a **string**, but should be converted into a **datetime object** for accurate time-based analysis.
#
# ---
#
# ### 📌 Column: `release_year`
#
# - **Validity Issue**
#   Currently stored as an **object**, but should be an **integer** or **datetime** for chronological analysis.
#
# ---
#
# ### 📌 Column: `duration`
#
# - **Consistency Issue**
#   Mixed formats:
#   - Movies: `'91 min'`, `'80 min'`
#   - TV Shows: `'1 Season'`, `'3 Seasons'`
#   This inconsistency hinders analysis.
#
# ---
#
# ## 🧹 2. **Messy Data**
#
# Messy data refers to unstructured or inconsistently formatted data not ready for direct analysis.
#
# ### 📌 Column: `duration`
#
# - **Consistency Problem**
#   Example: Movie `"The School of Mischief"` listed as **253 minutes**, but actual duration is **110 minutes** — shows incorrect and unreliable values.
#
# ---
#
# ### 📌 Columns: `director`, `cast`, `listed_in`
#
# - **Structural Problem**
#   These columns often contain **multiple values in a single cell**, e.g.:
#   - `"Director A, Director B"`
#   - `"Actor 1, Actor 2, Actor 3"`
#   This violates the principle of **atomicity** — ideally, each cell should contain only **one value**.
#
# - **Consistency Issue**
#   Inconsistent formatting (e.g., commas with or without spaces) across rows makes splitting or filtering harder.
#
# ---
#
# ## ✅ Summary Table
#
# | Column         | Issue Type            | Data Quality Category | Data Quality Dimension | Description                                                       |
# |----------------|------------------------|------------------------|------------------------|-------------------------------------------------------------------|
# | `show_id`      | Duplicate, not useful  | Dirty Data             | Completeness, Quality  | Repeated titles, irrelevant for analysis                          |
# | `type`         | Wrong data type        | Dirty Data             | Consistency            | Should be categorical instead of object                           |
# | `date_added`   | Invalid format         | Dirty Data             | Validity               | Needs conversion to datetime                                       |
# | `release_year` | Invalid format         | Dirty Data             | Validity               | Should be integer or datetime                                      |
# | `duration`     | Inconsistent formats   | Dirty + Messy Data     | Consistency, Validity  | Mixed types + incorrect values                                    |
# | `director`     | Multiple values/cell   | Messy Data             | Structure, Consistency | Needs splitting; violates atomicity                               |
# | `cast`         | Multiple values/cell   | Messy Data             | Structure, Consistency | Multiple actors per cell; hard to analyze                         |
# | `listed_in`    | Multiple genres/cell   | Messy Data             | Structure, Consistency | Same structural and formatting inconsistency                      |

# %% [markdown]
# ### <b><font color="white"><h3>🔍 Issues with the Dataset – Netflix Titles:</b></font>

# %% [markdown]
# ---
#
# ## 🧽 Data Cleaning Order (Recommended Workflow)
#
# When cleaning the Netflix dataset, it's ideal to follow a logical sequence to improve data quality efficiently. Below is the recommended order:
#
# 1. **Quality ➤ Completeness**
#    - Handle missing values
#    - Remove duplicate records
#    - Ensure every record has necessary fields
#
# 2. **Structural ➤ Messy Data**
#    - Normalize columns containing multiple values (e.g., split `director`, `cast`, `listed_in`)
#    - Ensure each column contains atomic values (one value per cell)
#
# 3. **Quality ➤ Validity**
#    - Convert columns to correct data types (`date_added` ➝ datetime, `release_year` ➝ int)
#    - Remove or flag entries with impossible values (e.g., extremely long durations)
#
# 4. **Quality ➤ Accuracy**
#    - Cross-verify values with trusted external sources where possible
#    - Correct known inaccurate values (e.g., wrong durations)
#
# 5. **Quality ➤ Consistency**
#    - Standardize formats (e.g., consistent use of "min", "Season(s)", proper spacing in lists)
#    - Ensure categories or labels are uniform across the dataset
#
# ---

# %% [markdown]
# ### <b><font color="white"><h3>🔍 Displaying all column names in the DataFrame:</b></font>

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %% [markdown]
# <h3><b> 📝 Insight </b></h3>
#
# The dataset contains 12 columns capturing key attributes such as content ID, type (Movie/TV Show), title details, cast and crew information, country of origin, release and addition dates, content rating, duration, genres, and description. These columns provide a comprehensive foundation for analyzing Netflix’s content library.

# %% [markdown]
# ### <b><font color="white"><h2>✅ Solve Completeness Issues:</b></font>

# %% [markdown]
# <b><font color="white"><h3>🔍 Displaying basic information about the DataFrame:</b></font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 757.0+ KB

# %% [markdown]
# <h3><b> 📝 Insight </b></h3>
#
# The dataset contains **8,807 entries** and **12 columns**.
# There are **missing values** in the following columns: **'director'**, **'cast'**, **'country'**, and **'date_added'**.
# These missing values need to be handled during the **data cleaning process**.
# Most columns are of **object (text/string)** type.
# Only **'release_year'** is a **numeric (int64)** column.

# %% [markdown]
# <b><font color="white"><h3>🔍 Checking percentage of missing values in the all columns:</b></font>

# %%
# Check for null values in the all columns :
df.isnull().sum()/100
# Out:
# show_id          0.00
# type             0.00
# title            0.00
# director        26.34
# cast             8.25
# country          8.31
# date_added       0.10
# release_year     0.00
# rating           0.04
# duration         0.03
# listed_in        0.00
# dtype: float64

# %% [markdown]
# <h3><b> 📝 Insight </b></h3>
#
# A check on missing values (in % terms) shows the following:
# - **'director'** has the highest missing rate at **26.34%**.
# - **'cast'** and **'country'** also have significant missing values at **8.25%** and **8.31%**, respectively.
# - Minor missing values are found in **'date_added' (0.10%)**, **'rating' (0.04%)**, and **'duration' (0.03%)**.
# - The remaining columns are **complete (0% missing values)**.
# ➡️ These missing values need to be handled during the data cleaning phase to ensure analysis accuracy.

# %% [markdown]
# <b><font color="white"><h3>🔍 Function to Handle Missing Values in Specific Columns:</b></font>

# %%
def Unknown_Name(df, col):
    """
    Replaces NaN values in the specified column with 'Unknown_<column_name>'.

    Parameters:
    df (DataFrame): The input DataFrame.
    col (str): The column name where NaNs need to be replaced.

    Returns:
    DataFrame: The updated DataFrame with NaNs in the column replaced by 'Unknown_<col>'.
    """
    unknown_value = f"Unknown_{col}"
    df[col] = df[col].fillna(unknown_value)
    return df

# %%
for column in ['director', 'cast', 'country']:
    df = Unknown_Name(df, column)

# %% [markdown]
# 🔹 **Handling Missing Values in 'director', 'cast', and 'country' Columns:**
#
# The provided function `Unknown_Name` is used to replace `NaN` values in specific columns with a placeholder string. In this case, the function is applied to the **'director'**, **'cast'**, and **'country'** columns.
#
# 📝 **Insight:**
# - The missing values in the **'director'**, **'cast'**, and **'country'** columns are now replaced with placeholder values like `'Unknown_director'`, `'Unknown_cast'`, and `'Unknown_country'`.
# - This helps in preserving rows while making it clear which entries are missing data, avoiding the need to drop rows and thus keeping the dataset intact.
# - It is particularly useful for categorical data where missing entries might represent unknown information rather than irrelevant data.
# - Now, any missing director, cast, or country information is clearly labeled, making future analysis smoother and more transparent.
#
# This approach ensures no data is lost, and the missing values are easily identifiable.

# %% [markdown]
# <b><font color="white"><h3>🔍 Checking DataFrame Structure After Handling Missing Values:</b></font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 757.0+ KB

# %% [markdown]
# <b><font color="white"><h3>🔍 Checking Missing Values Percentage for 'date_added', 'duration', and 'rating' Columns:</b></font>

# %%
# Clean column names
df.columns = df.columns.str.strip()

# %%
# Check for null values in the date_added column:
df['date_added'].isnull().sum()/100
# Out:
# np.float64(0.1)

# %%
# Check for null values in the duration column :
df['duration'].isnull().sum()/100
# Out:
# np.float64(0.03)

# %%
# Check for null values in the rating column :
df['rating'].isnull().sum()/100
# Out:
# np.float64(0.04)

# %%
# Remove the letter 's' from each value in the 'show_id' column
df['show_id'] = df['show_id'].str.replace('s', '', regex=False)

# %% [markdown]
# ## **Optimizing Data Types for Memory Efficiency:**

# %%
# Converting show_id from int64 to int32 to Reduce Memory Usage
df['show_id'] = df['show_id'].astype('int32')

# %%
# Converting 'type' Column to Categorical for Efficient Storage and Analysis
df['type'] = df['type'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   int32
#  1   type          8807 non-null   category
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
# dtypes: category(1), int32(1), int64(1), object(8)
# memory usage: 662.5+ KB

# %% [markdown]
# ## **✅ Insight: Data Type Optimization for Improved Efficiency**
# To enhance the dataset's performance and reduce memory consumption, we optimized the data types of two specific columns:
#
# 1) `show_id`:
#
#  - Before: `object` type (string-based), which is memory-inefficient for numerical IDs.
#
#  - After: Converted to `int32`, a compact 32-bit integer format suitable for numeric identifiers.
#
#  - Impact: This conversion significantly reduces the memory footprint of this column while preserving all data values.
#
# 2) `type`:
#
#  - Before: Stored as `object`, even though it contains only a few unique values (e.g., `Movie`, `TV Show`).
#
#  - After: Converted to `category`, allowing pandas to store it internally using integer codes.
#
#  - Impact: This change improves memory efficiency and speeds up operations like grouping and filtering.
#
# **📉 Memory Usage Reduction:**
#
#  - Before: 757.0 KB
#
#  - After: 662.5 KB
#
#  - ✅ Total memory saved: ~94.5 KB (~12.5%)
#
# This optimization is especially valuable when scaling up or working with larger datasets, as it helps in faster processing and lower memory consumption without compromising data quality.

# %%
affected_ids = [5542, 5795, 5814]

# Step 2: Copy rating to duration
df.loc[df['show_id'].isin(affected_ids), 'duration'] = df.loc[df['show_id'].isin(affected_ids), 'rating']

# Step 3: Set rating to empty
df.loc[df['show_id'].isin(affected_ids), 'rating'] = ''

# Step 4: Clean and fill rating column most frequen "frequent"
df['rating'] = df['rating'].replace(' ', '').fillna('')
df.loc[df['rating'] == '', 'rating'] = 'TV-MA'

# %%
df[df['show_id'].isin(affected_ids)]
# Out:
#       show_id   type                                 title    director  \
# 5541     5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794     5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813     5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  TV-MA
# 5794  Louis C.K.  United States  September 16, 2016          2010  TV-MA
# 5813  Louis C.K.  United States     August 15, 2016          2015  TV-MA
#
#      duration listed_in
# 5541   74 min    Movies
# 5794   84 min    Movies
# 5813   66 min    Movies

# %% [markdown]
# ## **✅ Insight:**
# In a few records (`show_id 5542, 5795, and 5814`), the `duration` information was incorrectly stored in the `rating` column — likely due to a data entry or formatting issue during data collection.
#
# To correct this:
#
# - The values from the `rating` column were `shifted` back to the correct `duration` column.
#
# - The incorrect `rating` values were cleared.
#
# - Then, to ensure consistency, all blank or `missing rating entries` were filled with the `most frequent` value, `TV-MA`.
#
# This `correction improves data accuracy` and ensures the `rating and duration` columns contain meaningful and properly aligned values for each show.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   int32
#  1   type          8807 non-null   category
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
# dtypes: category(1), int32(1), int64(1), object(8)
# memory usage: 662.5+ KB

# %% [markdown]
# 📝 **Insight:**
#
#
# ## ✅ Overview of Key Columns:
#
# 1. **'date_added':**
#    - Missing Value %: 0.10%
#    - Insight: Very small amount of missing data.
#    - Action: Can be safely ignored or imputed depending on analysis.
#
# 2. **'duration':**
#    - Issue: Some values were incorrectly placed in the 'rating' column.
#    - Action Taken:
#      • For show_ids [5542, 5795, 5814], values from 'rating' were moved to 'duration'.
#    - Result: Duration data is now corrected and more consistent.
#
# 3. **'rating':**
#    - Missing Value %: 0.04%
#    - Issue: Some missing and misplaced values.
#    - Action Taken:
#      • Values wrongly stored in 'rating' were moved to 'duration'.
#      • Remaining null or empty values in 'rating' were filled with 'Adults' as default.
#    - Result: 'rating' column is now complete with no missing values.
#
# ## 🎯 Summary:
# - All key columns (date_added, duration, rating) now have minimal or no missing values.
# - Dataset is more consistent and ready for further analysis.

# %% [markdown]
# <b><font color="white"><h3>🔍 Filtering and Sorting Duplicates Based on Selected Columns:</b></font>

# %%
temp_df = df[df.duplicated(subset=['director', 'type', 'cast', 'country', 'date_added',
                         'release_year', 'rating', 'duration', 'listed_in'],keep=False)]\
  .sort_values(by='director')

# %% [markdown]
# 📝 **Insight:**
#
# - This code filters out the rows in the dataset where **duplicate entries** exist based on a combination of multiple columns (`'director'`, `'type'`, `'cast'`, `'country'`, `'date_added'`, `'release_year'`, `'rating'`, `'duration'`, and `'listed_in'`).
# - The `duplicated()` method is used with `keep=False`, ensuring **all instances of duplicate rows are kept**, not just the first or last occurrence.
# - The resulting duplicates are **sorted by the 'director' column** for easier analysis.
#
# This process helps to identify **exact duplicates** based on multiple features, allowing you to either **remove them** or investigate them further for potential data issues.

# %%
temp_df
# Out:
#       show_id     type                                              title  \
# 3568     3569    Movie                          Game Over (Hindi Version)
# 3570     3571    Movie                         Game Over (Telugu Version)
# 3493     3494    Movie                                   Oh! Baby (Tamil)
# 3492     3493    Movie                               Oh! Baby (Malayalam)
# 5466     5467    Movie                The Mitfords: A Tale of Two Sisters
# 5448     5449    Movie                      Amelia: A Tale of Two Sisters
# 5451     5452    Movie                      Jackie: A Tale of Two Sisters
# 759       760    Movie  Fireplace 4K: Classic Crackling Fireplace from...
# 760       761    Movie  Fireplace 4K: Crackling Birchwood from Firepla...
# 3371     3372    Movie                                       Consequences
# 6529     6530    Movie                                      Consequences
# 5965     5966    Movie                                             22-Jul
# ...

# %% [markdown]
# 📝 **Insight:**
#
# The `temp_df` DataFrame contains all the **duplicate rows** from the original dataset based on the specified columns. After filtering and identifying duplicates, the dataset is sorted by the 'director' column for easy examination.
#
# This DataFrame helps to visualize and further analyze rows that are exact duplicates, giving insights into potential data quality issues that may require cleaning (e.g., removing or correcting duplicate entries).

# %% [markdown]
# <b><font color="white"><h4>🔍 Checking the Shape of Filtered Duplicates:</b></font>

# %%
temp_df.shape
# Out:
# (35, 11)

# %%
temp_df
# Out:
#       show_id     type                                              title  \
# 3568     3569    Movie                          Game Over (Hindi Version)
# 3570     3571    Movie                         Game Over (Telugu Version)
# 3493     3494    Movie                                   Oh! Baby (Tamil)
# 3492     3493    Movie                               Oh! Baby (Malayalam)
# 5466     5467    Movie                The Mitfords: A Tale of Two Sisters
# 5448     5449    Movie                      Amelia: A Tale of Two Sisters
# 5451     5452    Movie                      Jackie: A Tale of Two Sisters
# 759       760    Movie  Fireplace 4K: Classic Crackling Fireplace from...
# 760       761    Movie  Fireplace 4K: Crackling Birchwood from Firepla...
# 3371     3372    Movie                                       Consequences
# 6529     6530    Movie                                      Consequences
# 5965     5966    Movie                                             22-Jul
# ...

# %% [markdown]
# <b><font color="white"><h3>🔍 Dropping Specific Duplicate Rows from the Dataset:</b></font>

# %%
# Dropped the rows duplicated rows:
temp_df.drop([3570,3568,3492,3493,5466,5451,5448,760,759,414,413,411,406,416,424,236,237,238,239,8051,8052,851,852,4831,4832,6785,8129], axis=0,inplace=True)

# %% [markdown]
# 📝 Insight:
#
# The code removes specific duplicate rows from the temp_df DataFrame based on their row indices. By using the drop() method, these rows are eliminated from the dataset to ensure that only unique entries remain.
#
# This step helps in cleaning the data further by removing exact duplicates that may have been introduced during the earlier filtering or data collection process.

# %%
df = df[~df.index.isin(temp_df.index)]

# %%
# Checked the Null Value :
df.duplicated(subset='title').sum()
# Out:
# np.int64(0)

# %% [markdown]
# <b><font color="white"><h3>🔍 Displaying Dataset Info After Cleaning:</b></font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8799 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8799 non-null   int32
#  1   type          8799 non-null   category
#  2   title         8799 non-null   object
#  3   director      8799 non-null   object
#  4   cast          8799 non-null   object
#  5   country       8799 non-null   object
#  6   date_added    8789 non-null   object
#  7   release_year  8799 non-null   int64
#  8   rating        8799 non-null   object
#  9   duration      8799 non-null   object
#  10  listed_in     8799 non-null   object
# dtypes: category(1), int32(1), int64(1), object(8)
# memory usage: 730.5+ KB

# %% [markdown]
# 📝 **Insight**:
#
# After removing the duplicates from the original DataFrame (`df`), the dataset has been reduced from 8,807 entries to 8,792 entries. Here's a detailed breakdown:
#
# - **Original Data**: The original dataset had 8,807 entries with some missing values in columns such as 'date_added', 'rating', and 'duration'.
# - **Post-Duplication Removal**: After removing the duplicates, 15 duplicate rows were removed, leaving a clean dataset with 8,792 entries.
#
#   **Key Points**:
#   - **Missing Values**: Some missing values still persist in columns like 'date_added', 'rating', and 'duration', but these columns now have fewer missing entries compared to before the duplicate removal.
#   - **Consistency**: The number of rows has decreased by 15, but the remaining dataset is cleaner without duplicate entries.
#
# By removing the duplicates, the dataset is now more accurate and should provide more reliable insights for analysis. However, further steps such as handling the missing values in specific columns may be needed to ensure the data is ready for analysis.

# %% [markdown]
# ### <b><font color="white"><h3>🔍 Solving Data Quality Issues:</b></font>

# %%
# Convert type column data type :
df['type'] = df['type'].astype('category')

# %%
# Convert date_added column data type :
df['date_added'] = pd.to_datetime(df['date_added'].str.strip(), errors='coerce')

# %%
# convert release_year column
df['release_year'] = df['release_year'].astype(int)

# %% [markdown]
# 📝 Insight:
#
# The data cleaning process has successfully addressed several quality issues:
#
# 1. The 'show_id' column has been cleaned by removing any unwanted 's' characters that could cause inconsistencies.
#
# 2. The 'type' column has been converted to a category type, which helps improve performance, especially when working with a large dataset, as categories consume less memory.
#
# 3. The 'date_added' column has been converted to a datetime type, ensuring proper date-based analysis. Any errors encountered during this conversion have been handled using `errors='coerce'`, which replaces invalid values with NaT (Not a Time).
#
# 4. The 'release_year' column has been converted to integer type to ensure consistent numerical representation for analysis.
#
# These changes address key quality issues, making the dataset more consistent and ready for analysis.

# %% [markdown]
# ### <b><font color="white"><h3>🔍 Solving Structural and Consistency Issues:</b></font>

# %% [markdown]
# **"Inconsistent Naming in Duration Column: 'Season' vs 'Seasons'"**
#
#
# This heading clearly indicates that there's a mismatch between the singular ("Season") and plural ("Seasons") forms, which is affecting the consistency of the data.

# %%
# Ensure all values in the 'duration' column are strings
df['duration'] = df['duration'].str.strip().astype(str)

# Replace 'Seasons' with 'Season' only where applicable
df['duration'] = df['duration'].apply(lambda x: x.replace('Seasons', 'Season') if 'Seasons' in x else x)

# %%
# Checking the after replace 'Seasons' with 'Season':
df.sample(5)
# Out:
#       show_id     type          title           director  \
# 1590     1591  TV Show      Big Mouth   Unknown_director
# 452       453    Movie  A Perfect Fit  Hadrah Daeng Ratu
# 5376     5377    Movie  Chasing Coral      Jeff Orlowski
# 331       332  TV Show  Darwin’s Game   Unknown_director
# 5846     5847    Movie    The Do-Over       Steven Brill
#
#                                                    cast          country  \
# 1590  Nick Kroll, John Mulaney, Jessi Klein, Jason M...    United States
# 452   Nadya Arina, Refal Hady, Giorgino Abraham, Ang...        Indonesia
# 5376                                       Unknown_cast    United States
# 331   Yusuke Kobayashi, Reina Ueda, Nichika Omori, T...  Unknown_country
# 5846  Adam Sandler, David Spade, Paula Patton, Kathr...    United States
#
#      date_added  release_year rating  duration  \
# 1590 2020-12-04          2020  TV-MA  4 Season
# 452  2021-07-15          2021  TV-PG   113 min
# ...

# %% [markdown]
# ### <b><font color="white"><h3>🔍 Unstacking and Exploding Columns to Handle Multiple Values:</b></font>

# %%
def unstack_col(df, col):
    # Ensure values are strings or keep NaNs as-is
    df[col] = df[col].apply(lambda x: x.strip() if isinstance(x, str) else x)

    # Split only strings by comma
    df[col] = df[col].apply(lambda x: x.split(',') if isinstance(x, str) else x)

    # Explode and remove NaNs from that column
    df = df.explode(col).dropna(subset=[col]).reset_index(drop=True)

    return df

# %%
# Apply to all required columns
for column in ['director', 'cast', 'country', 'listed_in']:
    df = unstack_col(df, column)

# %% [markdown]
# 📝 Insight:
#
# The unstack_col function is designed to handle columns that contain multiple values in a single cell, such as lists or comma-separated values. Here's what happens:
#
# 1. String Stripping: It strips any leading or trailing spaces from string values.
# 2. Splitting Values: For each string, it splits the values by a comma, creating a list of values.
# 3. Exploding: The explode() method then transforms each value in the list into a separate row, effectively "unstacking" the values.
# 4. Removing NaNs: After exploding, any resulting NaN values are dropped to ensure the cleaned dataset only contains valid entries.
#
# By applying this function to columns like 'director', 'cast', 'country', and 'listed_in', we can ensure that each individual value is represented in a separate row, facilitating more accurate analysis and improving the overall data quality.

# %% [markdown]
# ### <b><font color="white"><h3>🔍 Data Info After Unstacking the Columns:</b></font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201845 entries, 0 to 201844
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   show_id       201845 non-null  int32
#  1   type          201845 non-null  category
#  2   title         201845 non-null  object
#  3   director      201845 non-null  object
#  4   cast          201845 non-null  object
#  5   country       201845 non-null  object
#  6   date_added    201687 non-null  datetime64[ns]
#  7   release_year  201845 non-null  int64
#  8   rating        201845 non-null  object
#  9   duration      201845 non-null  object
#  10  listed_in     201845 non-null  object
# dtypes: category(1), datetime64[ns](1), int32(1), int64(1), object(7)
# memory usage: 14.8+ MB

# %% [markdown]
#  📝 Insight
#
# - **Row Expansion:**
#   After unstacking the multivalued columns (`director`, `cast`, `country`, and `listed_in`), the number of rows increased from **8,807** to **201,835**. This is expected, as each comma-separated value is now a separate row — allowing for more detailed and accurate analysis.
#
# - **Improved Data Quality:**
#   Each row now reflects a **single atomic value** per field, making it easier to **group, filter, and visualize** key relationships like frequent actors, countries, or genres.
#
# - **Higher Memory Usage:**
#   Due to the row expansion, memory usage has increased. However, this trade-off leads to a much **cleaner and analysis-friendly structure**.
#
# - **Data Type Enhancements:**
#   - `date_added` was converted to `datetime` format.
#   - `type` is now a categorical variable, which improves performance and consistency.
#
# > ✅ This transformation was essential for converting nested or compound fields into a tidy format, which is foundational for reliable data exploration and visualization.

# %% [markdown]
# ### <b><font color="white"><h3>🔍 Checking for Duplicate Rows After Unstacking and Delete :</b></font>

# %%
# Count of duplicate rows
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 55

# %%
# delete the duplicate rows:
df[df.duplicated()]
# Out:
#         show_id   type                title        director  \
# 39354      1632  Movie           Rust Creek     Jen McGowan
# 88536      3719  Movie      Blood Will Tell    Miguel Cohan
# 88537      3719  Movie      Blood Will Tell    Miguel Cohan
# 88538      3719  Movie      Blood Will Tell    Miguel Cohan
# 88539      3719  Movie      Blood Will Tell    Miguel Cohan
# 88540      3719  Movie      Blood Will Tell    Miguel Cohan
# 88541      3719  Movie      Blood Will Tell    Miguel Cohan
# 88542      3719  Movie      Blood Will Tell    Miguel Cohan
# 88543      3719  Movie      Blood Will Tell    Miguel Cohan
# 88544      3719  Movie      Blood Will Tell    Miguel Cohan
# 88545      3719  Movie      Blood Will Tell    Miguel Cohan
# 88546      3719  Movie      Blood Will Tell    Miguel Cohan
# 88547      3719  Movie      Blood Will Tell    Miguel Cohan
# 88548      3719  Movie      Blood Will Tell    Miguel Cohan
# 88549      3719  Movie      Blood Will Tell    Miguel Cohan
# ...

# %%
# Dropped the rows duplicated rows:
df.drop([39354, 135656, 135657, 135658, 135659, 135660, 135661], axis=0,inplace=True)

# %% [markdown]
# ### <b><font color="white"><h3>🔍 Checking DataFrame After Duplicate Rows Delete :</b></font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201838 entries, 0 to 201844
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   show_id       201838 non-null  int32
#  1   type          201838 non-null  category
#  2   title         201838 non-null  object
#  3   director      201838 non-null  object
#  4   cast          201838 non-null  object
#  5   country       201838 non-null  object
#  6   date_added    201680 non-null  datetime64[ns]
#  7   release_year  201838 non-null  int64
#  8   rating        201838 non-null  object
#  9   duration      201838 non-null  object
#  10  listed_in     201838 non-null  object
# dtypes: category(1), datetime64[ns](1), int32(1), int64(1), object(7)
# memory usage: 16.4+ MB

# %% [markdown]
# ### <b><font color="white"><h3>🔍 Check the Percentage of Missing Values in `date_added` Column:</b></font>

# %%
# Check the null value in the date_added column:
df['date_added'].isnull().sum()
# Out:
# np.int64(158)

# %% [markdown]
# 📝 **Insight:**
#
# There are 158 missing values in the `date_added` column. This indicates that the exact date when the content was added to the platform is unknown for these records. Addressing these missing entries is important for accurate time-based analysis such as content addition trends over the years.

# %% [markdown]
# ### <b><font color="white"><h3>🛠️ Imputing Missing `date_added` Values Using Most Frequent Dates by `release_year`:</b></font>

# %%
# Count of Missing `date_added` Values Grouped by `release_year`:
df[df['date_added'].isnull()]['release_year'].value_counts()
# Out:
# release_year
# 2015    40
# 2008    36
# 2013    27
# 2003    24
# 2012    24
# 2016     5
# 2018     1
# 2010     1
# Name: count, dtype: int64

# %%
# Just i will check the most frequently date for fill the null value:
df[df['date_added'].dt.year == 2015]['date_added'].value_counts().head(1)
# Out:
# date_added
# 2015-10-25    195
# Name: count, dtype: int64

# %%
df.loc[df['date_added'].isnull() & (df['release_year'] == 2015), 'date_added'] = pd.to_datetime('2015-12-17')
(df['date_added'].isnull() & (df['release_year'] == 2015)).sum()
# Out:
# np.int64(0)

# %%
# Just i will check the most frequently date for fill the null value:
df[df['date_added'].dt.year == 2013]['date_added'].value_counts().head(1)
# Out:
# date_added
# 2013-09-01    49
# Name: count, dtype: int64

# %%
df.loc[df['date_added'].isnull() & (df['release_year'] == 2013), 'date_added'] = pd.to_datetime('2013-12-29')
(df['date_added'].isnull() & (df['release_year'] == 2013)).sum()
# Out:
# np.int64(0)

# %%
# Just i will check the most frequently date for fill the null value:
df[df['date_added'].dt.year == 2008]['date_added'].value_counts().head(1)
# Out:
# date_added
# 2008-01-01    18
# Name: count, dtype: int64

# %%
df.loc[df['date_added'].isnull() & (df['release_year'] == 2008), 'date_added'] = pd.to_datetime('2008-01-01')
(df['date_added'].isnull() & (df['release_year'] == 2008)).sum()
# Out:
# np.int64(0)

# %%
# Just i will check the most frequently date for fill the null value:
df[df['date_added'].dt.year == 2012]['date_added'].value_counts().head(1)
# Out:
# date_added
# 2012-12-01    18
# Name: count, dtype: int64

# %%
df.loc[df['date_added'].isnull() & (df['release_year'] == 2012), 'date_added'] = pd.to_datetime('2012-12-01')
(df['date_added'].isnull() & (df['release_year'] == 2012)).sum()
# Out:
# np.int64(0)

# %%
# Just i will check the most frequently date for fill the null value:
df[df['date_added'].dt.year == 2016]['date_added'].value_counts().head().head(1)
# Out:
# date_added
# 2016-01-01    726
# Name: count, dtype: int64

# %%
df.loc[df['date_added'].isnull() & (df['release_year'] == 2016), 'date_added'] = pd.to_datetime('2016-01-01')
(df['date_added'].isnull() & (df['release_year'] == 2016)).sum()
# Out:
# np.int64(0)

# %%
# Just i will check the most frequently date for fill the null value:
df[df['date_added'].dt.year == 2018]['date_added'].value_counts().head(1)
# Out:
# date_added
# 2018-03-01    1752
# Name: count, dtype: int64

# %%
df.loc[df['date_added'].isnull() & (df['release_year'] == 2018), 'date_added'] = pd.to_datetime('2018-03-01')
(df['date_added'].isnull() & (df['release_year'] == 2018)).sum()
# Out:
# np.int64(0)

# %%
# Just i will check the most frequently date for fill the null value:
df[df['date_added'].dt.year == 2010]['date_added'].value_counts().head(1)
# Out:
# date_added
# 2010-11-01    20
# Name: count, dtype: int64

# %%
df.loc[df['date_added'].isnull() & (df['release_year'] == 2010), 'date_added'] = pd.to_datetime('2010-11-01')
(df['date_added'].isnull() & (df['release_year'] == 2010)).sum()
# Out:
# np.int64(0)

# %%
df.loc[df['date_added'].isnull() & (df['release_year'] == 2003), 'date_added'] = pd.to_datetime('2019-11-15')
(df['date_added'].isnull() & (df['release_year'] == 2003)).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 🛠️ Filling Missing `date_added` Values Based on Most Frequent Dates by Release Year
#
# - Total missing `date_added` entries: **158**
#
# - Breakdown by `release_year` (for missing entries):
#   - **2015** → 40 missing → Filled with: `2015-12-17`
#   - **2008** → 36 missing → Filled with: `2008-01-01`
#   - **2013** → 27 missing → Filled with: `2013-12-29`
#   - **2003** → 24 missing → Filled with: `2019-11-15` _(defaulted as no existing `date_added` for 2003)_
#   - **2012** → 24 missing → Filled with: `2012-12-01`
#   - **2016** → 5 missing → Filled with: `2016-01-01`
#   - **2018** → 1 missing → Filled with: `2018-03-01`
#   - **2010** → 1 missing → Filled with: `2010-11-01`
#
# 📝 **Insight**:
# This imputation process uses the most common `date_added` values within each `release_year` group to fill the missing data. This method ensures:
# - 🔄 Logical consistency between `release_year` and `date_added`.
# - 📊 Improved data completeness (nulls reduced from **158 to 0**).
# - 🧹 Better time-based analysis without distorting trends.

# %% [markdown]
# ### <b><font color="white"><h3>🔍 Checking After Imputing Missing `date_added` Values based on `release_year`:</b></font>

# %%
# Check the null value after imputing missing value:
df['date_added'].isnull().sum()/100
# Out:
# np.float64(0.0)

# %% [markdown]
# - Checked the remaining null values in the `date_added` column **after filling** them based on `release_year`.
# - Output: **0.0**, meaning **all 158 missing values have been successfully imputed**.
# - Now the `date_added` column is **100% complete**, making it reliable for time-series or trend-based analysis.

# %% [markdown]
# ### <b><font color="white"><h3>🔍 Check the Percentage of Missing Values in `rating` Column:</b></font>

# %%
# Check the null value in the rating column:
df['rating'].isnull().sum()/100
# Out:
# np.float64(0.0)

# %% [markdown]
# ### <b><font color="white"><h3>🔍 Missing Rating Imputation and Top `Ratings` by `Type`:</b></font>

# %%
# Check the most frequency rating
top_ratings_by_type = df.groupby('type')['rating'].value_counts().groupby(level=0).head(3)
# Out:
# <ipython-input-69-4a48cc602680>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   top_ratings_by_type = df.groupby('type')['rating'].value_counts().groupby(level=0).head(3)
# <ipython-input-69-4a48cc602680>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   top_ratings_by_type = df.groupby('type')['rating'].value_counts().groupby(level=0).head(3)

# %%
print(top_ratings_by_type)
# Out:
# type     rating
# Movie    TV-MA     43973
#          TV-14     29218
#          R         25715
# TV Show  TV-MA     29964
#          TV-14     14651
#          TV-PG      4614
# Name: count, dtype: int64

# %%
# most frequency rating Movies & TV Show "TV-MA"
df.loc[df['rating'].isnull(), 'rating'] = 'TV-MA'

# %% [markdown]
# # 📝 Insights:
#
# 1. **Missing Ratings Imputation**:
#    - Missing values in the `rating` column were identified and imputed with the value `'TV-MA'`.
#    - This approach ensures that missing ratings do not result in null values, keeping the dataset consistent for analysis.
#    - Imputation with a standard rating (like `'TV-MA'`) helps to avoid biases that might arise from excluding rows with missing values.
#
# 2. **Top Ratings by Type**:
#    - The top 3 most frequent ratings for each content type (e.g., TV shows and movies) were identified using `groupby()` and `value_counts()`.
#    - This helps in understanding the distribution of ratings across different types of content.
#    - By observing the most common ratings for each content type, we can make informed decisions regarding audience preferences and content categorization.
#
# 3. **Data Quality**:
#    - Imputing missing ratings and analyzing the rating distribution by content type improves the data quality.
#    - A complete and well-structured dataset ensures better insights and more reliable analysis, especially when working with ratings for content recommendations or analysis.

# %% [markdown]
# ### <b><font color="white"><h3>🔍 Checking After Imputing Missing `rating` Values based on `type`:</b></font>

# %%
# Check the null value after imputing missing value in the rating column:
df['rating'].isnull().sum()/100
# Out:
# np.float64(0.0)

# %% [markdown]
# ### <b><font color="white"><h3>🔍 Again checking the DataFrame After Imputing Missing `rating` Values based on `type`:</b></font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201838 entries, 0 to 201844
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   show_id       201838 non-null  int32
#  1   type          201838 non-null  category
#  2   title         201838 non-null  object
#  3   director      201838 non-null  object
#  4   cast          201838 non-null  object
#  5   country       201838 non-null  object
#  6   date_added    201838 non-null  datetime64[ns]
#  7   release_year  201838 non-null  int64
#  8   rating        201838 non-null  object
#  9   duration      201838 non-null  object
#  10  listed_in     201838 non-null  object
# dtypes: category(1), datetime64[ns](1), int32(1), int64(1), object(7)
# memory usage: 16.4+ MB

# %% [markdown]
# ### <b><font color="white"><h2>🔍 Handling Character Encoding Errors in Text Data Like `최강전사 미니특공대 : 영웅의 탄생	`:</b></font>

# %%
df.groupby('title', observed=True)['show_id'].nunique().tail()
# Out:
# title
# 忍者ハットリくん               1
# 海的儿子                   1
# 마녀사냥                   1
# 반드시 잡는다                1
# 최강전사 미니특공대 : 영웅의 탄생    1
# Name: show_id, dtype: int64

# %%
df.groupby('director', observed=True)['show_id'].nunique().sample(5)
# Out:
# director
# Eddie Martin          1
# Kalvadour Peterson    1
# Randall Lobb          2
# Aurora Guerrero       1
# Robert Eagar          1
# Name: show_id, dtype: int64

# %%
df.groupby('cast', observed=True)['show_id'].nunique().head(5)
# Out:
# cast
# "Riley" Lakdhar Dridi    1
# 'Najite Dede             2
# 2 Chainz                 1
# 2Mex                     1
# 4Minute                  1
# Name: show_id, dtype: int64

# %% [markdown]
# 📝 Insight:
#
# While exploring the `title`, `director` & `cast` columns, I observed the presence of non-English titles such as `최강전사 미니특공대 : 영웅의 탄생`, which is in Korean. This indicates that the dataset contains multilingual and region-specific content. Such diversity reflects Netflix’s global reach and supports potential analyses based on language, region, or audience preferences.

# %% [markdown]
# ### <b><font color="white"><h2>🔍 Assigning Meaningful Age-Based Ratings to Understand Content Classification:</b></font>

# %%
# Check the unique ratings:
df.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# 📊 **Understanding the Meaning of Each Rating**
#
# Each rating follows industry standards set by organizations such as the MPAA (Motion Picture Association of America) and the TV Parental Guidelines. These definitions help categorize content based on age-appropriateness.
#
# 🔤 **Examples:**
#
# - 🔞 **TV-MA** – Mature Audience (Adults only)
# - 👶 **TV-Y** – Suitable for young kids
# - 👦 **PG-13** – Teens (13+)
# - 👨‍👩‍👧 **TV-PG** – Parental Guidance (Older kids)
# - 🚫 **R** – Restricted (17+)
# - ⛔ **NC-17** – No one under 17 permitted

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df['rating'].sample(5)
# Out:
# 84015     TV-14
# 175861       PG
# 27909         R
# 55718     TV-MA
# 72126         R
# Name: rating, dtype: object

# %%
# Changing the values in the rating column :
Rating_Map = {'TV-MA' : 'Adults',
              'R' : 'Adults',
              'PG-13':'Teens',
              'TV-14':'Young Adults',
              'TV-PG':'Older Kids',
              'NR':'Adults',
              'TV-G':'Kids',
              'TV-Y':'Kids',
              'TV-Y7':'Older Kids',
              'PG':'Older Kids',
              'G':'Kids',
              'NC-17':'Adults',
              'TV-Y7-FV':'Older Kids',
              'UR':'Adults'
}

# %%
df['rating'].replace(Rating_Map, inplace=True)
# Out:
# <ipython-input-80-7439b669392a>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rating'].replace(Rating_Map, inplace=True)

# %%
df['rating'] = df['rating'].astype('category')

# %%
df['rating'].sample(5)
# Out:
# 177420    Young Adults
# 23563            Teens
# 123503          Adults
# 37482     Young Adults
# 120912          Adults
# Name: rating, dtype: category
# Categories (5, object): ['Adults', 'Kids', 'Older Kids', 'Teens', 'Young Adults']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201838 entries, 0 to 201844
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   show_id       201838 non-null  int32
#  1   type          201838 non-null  category
#  2   title         201838 non-null  object
#  3   director      201838 non-null  object
#  4   cast          201838 non-null  object
#  5   country       201838 non-null  object
#  6   date_added    201838 non-null  datetime64[ns]
#  7   release_year  201838 non-null  int64
#  8   rating        201838 non-null  category
#  9   duration      201838 non-null  object
#  10  listed_in     201838 non-null  object
# dtypes: category(2), datetime64[ns](1), int32(1), int64(1), object(6)
# memory usage: 15.0+ MB

# %% [markdown]
# **Categorizing Ratings into Broad Audience Groups**

# %% [markdown]
# # 📝 Insight:
#
# This transformation simplifies the original rating system by mapping several specific content ratings into broader, age-based categories such as Kids, Older Kids, Teens, Young Adults, and Adults. This step offers several benefits that enhance both data quality and analytical utility:
#
# *`✅ Enhanced Readability`*
#
# The original rating codes like 'TV-MA', 'PG-13', or 'NC-17' can be complex or inconsistent for interpretation. By converting them into broader terms, the dataset becomes much easier to read and understand at a glance.
#
# *`📊 Improved Analysis`*
#
# Grouping ratings allows for better aggregation and comparison. For example, it's now easy to analyze how much content is targeted at Kids vs. Adults without dealing with fragmented categories.
#
# *`🔍 Facilitates Segmentation`*
#
# This mapping supports content segmentation for recommendation systems and marketing. You can now easily target specific age-based groups like 'Teens' or 'Young Adults' with personalized suggestions.
#
# *`🧼 Data Cleaning`*
#
# This step unifies equivalent or overlapping ratings (e.g., 'TV-MA', 'R', 'NC-17', 'UR' → 'Adults'), reducing inconsistencies and helping ensure the data is clean and standardized.
#
# *`📉 Reduces Complexity`*
#
# Converting 14+ detailed ratings into just 5 broad categories simplifies visualizations, statistics, and model training — while still preserving the core meaning of the content classification.
#
# ➡️ Overall, this is a crucial data preprocessing step that enhances the value and usability of the 'rating' column for downstream tasks like modeling, reporting, and visualization.

# %%
# Count of duplicate rows
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 54

# %%
df.isnull().sum()/100
# Out:
# show_id         0.0
# type            0.0
# title           0.0
# director        0.0
# cast            0.0
# country         0.0
# date_added      0.0
# release_year    0.0
# rating          0.0
# duration        0.0
# listed_in       0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201838 entries, 0 to 201844
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   show_id       201838 non-null  int32
#  1   type          201838 non-null  category
#  2   title         201838 non-null  object
#  3   director      201838 non-null  object
#  4   cast          201838 non-null  object
#  5   country       201838 non-null  object
#  6   date_added    201838 non-null  datetime64[ns]
#  7   release_year  201838 non-null  int64
#  8   rating        201838 non-null  object
#  9   duration      201838 non-null  object
#  10  listed_in     201838 non-null  object
# dtypes: category(1), datetime64[ns](1), int32(1), int64(1), object(7)
# memory usage: 16.4+ MB

# %% [markdown]
# ### <b><font color="white"><h2>✅ Final Cleaned Dataset: Ready for Analysis, Visualization, or Model Building:</b></font>

# %% [markdown]
# This heading clearly indicates that your dataset has undergone all necessary preprocessing steps—missing value treatment, data transformation, standardization, and encoding—and is now fully prepared for the next stages such as:
#
# - 📊 Exploratory Data Analysis (EDA)
#
# - 📈 Building visualizations and dashboards
#
# - 🤖 Feeding into machine learning models
#
# - 📤 Exporting and sharing with others for collaboration

# %% [markdown]
# ### <b><font color="white"><h2>🔍 Exporting the Cleaned DataFrame to CSV and Triggering Download:</b></font>

# %%
# df = pd.DataFrame(df)

# filename = 'df.csv'
# df.to_csv(filename, index=False)

# files.download(filename)
# print(f"DataFrame saved as '{df}' and ready for download.")

# %% [markdown]
# # 📝 Insight:
#
# Downloading the `Netflix cleaned DataFrame` as a CSV file opens up several possibilities for further work, sharing, and integration:
#
# `✅ Data Backup: `
#
# Ensures you have a saved copy of your cleaned and transformed data for future use or recovery.
#
# `📊 Further Analysis: `
#
# You can import this CSV into tools like Excel, Google Sheets, Tableau, or Power BI for advanced visualization and reporting.
#
# `📤 Sharing with Others: `
#
# A CSV file is easy to share with teammates, instructors, or clients who may not be using Python or Jupyter Notebooks.
#
# `🤖 Use in ML Models: `
#
# The cleaned data can now be used as input for machine learning models in tools like scikit-learn, TensorFlow, or cloud platforms.
#
# `🧪 Version Control: `
#
# Keeping a saved version of your processed data helps track progress, especially when working with different stages of preprocessing.
#
# `📥 Cross-Platform Integration: `
#
# CSVs are universally supported, making it easier to move data between systems or applications (e.g., importing into SQL databases, dashboards, or APIs).

# %%
df.shape
# Out:
# (201838, 11)

# %%
df.groupby("type")["title"].nunique()
# Out:
# <ipython-input-87-adaec64cb97e>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("type")["title"].nunique()
# type
# Movie      6125
# TV Show    2674
# Name: title, dtype: int64

# %%
def check_null_value(df):
    result = {}

    for col in df.columns:
        result[col] = df[col].isnull().sum() / 100

    return result

# %%
null_value = check_null_value(df)
pd.DataFrame.from_dict(null_value, orient='index', columns=['null_ratio'])
# Out:
#               null_ratio
# show_id              0.0
# type                 0.0
# title                0.0
# director             0.0
# cast                 0.0
# country              0.0
# date_added           0.0
# release_year         0.0
# rating               0.0
# duration             0.0
# listed_in            0.0

# %%
df[df['country'] == '']
# Out:
#         show_id     type          title          director  \
# 4737        194  TV Show           D.P.  Unknown_director
# 4738        194  TV Show           D.P.  Unknown_director
# 4741        194  TV Show           D.P.  Unknown_director
# 4742        194  TV Show           D.P.  Unknown_director
# 4745        194  TV Show           D.P.  Unknown_director
# ...         ...      ...            ...               ...
# 159091     7008    Movie  Hotel Pacific   Janusz Majewski
# 159092     7008    Movie  Hotel Pacific   Janusz Majewski
# 159096     7008    Movie  Hotel Pacific   Janusz Majewski
# 159097     7008    Movie  Hotel Pacific   Janusz Majewski
# 159098     7008    Movie  Hotel Pacific   Janusz Majewski
#
#                          cast country date_added  release_year  rating  \
# 4737              Jung Hae-in         2021-08-27          2021  Adults
# 4738              Jung Hae-in         2021-08-27          2021  Adults
# ...

# %%
df.loc[df['country'] == '', 'country'] = 'South Korea'
df['country'].fillna('South Korea', inplace=True)
# Out:
# <ipython-input-91-a0c1bc7c3008>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].fillna('South Korea', inplace=True)

# %%
df['country'].str.strip()
# Out:
# 0         United States
# 1          South Africa
# 2          South Africa
# 3          South Africa
# 4          South Africa
#               ...
# 201840            India
# 201841            India
# 201842            India
# 201843            India
# 201844            India
# Name: country, Length: 201838, dtype: object

# %%
df[df['cast'].isin(['Jung Hae-in'])]
# Out:
#         show_id     type                  title          director  \
# 4737        194  TV Show                   D.P.  Unknown_director
# 4738        194  TV Show                   D.P.  Unknown_director
# 4739        194  TV Show                   D.P.  Unknown_director
# 4740        194  TV Show                   D.P.  Unknown_director
# 79577      3309    Movie       Tune in for Love       Jung Ji-woo
# 79578      3309    Movie       Tune in for Love       Jung Ji-woo
# 79579      3309    Movie       Tune in for Love       Jung Ji-woo
# 87734      3674  TV Show       One Spring Night  Unknown_director
# 87735      3674  TV Show       One Spring Night  Unknown_director
# 87736      3674  TV Show       One Spring Night  Unknown_director
# 112304     4849  TV Show  Something in the Rain  Unknown_director
# 112305     4849  TV Show  Something in the Rain  Unknown_director
# 112306     4849  TV Show  Something in the Rain  Unknown_director
#
# ...

# %%
df.sample(5)
# Out:
#         show_id     type                        title  \
# 103083     4415    Movie                Ana e Vitória
# 74062      3096  TV Show       The Bonfire of Destiny
# 18936       744    Movie                   Copenhagen
# 51979      2195  TV Show                 Unlucky Ploy
# 134745     5977    Movie  Çok Filim Hareketler Bunlar
#
#                        director                   cast          country  \
# 103083            Matheus Souza        Bruce Gomlevsky           Brazil
# 74062          Unknown_director        Josiane Balasko           France
# 18936                 Mark Raso              Baard Owe           Canada
# 51979   Nopparoj Chotmunkongsit  Kittiphong Dumavibhat  Unknown_country
# 134745             Ozan Açıktan           Ayça Erturan           Turkey
#
#        date_added  release_year  rating  duration             listed_in
# 103083 2018-11-02          2018  Adults   116 min          LGBTQ Movies
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201838 entries, 0 to 201844
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   show_id       201838 non-null  int32
#  1   type          201838 non-null  category
#  2   title         201838 non-null  object
#  3   director      201838 non-null  object
#  4   cast          201838 non-null  object
#  5   country       201838 non-null  object
#  6   date_added    201838 non-null  datetime64[ns]
#  7   release_year  201838 non-null  int64
#  8   rating        201838 non-null  category
#  9   duration      201838 non-null  object
#  10  listed_in     201838 non-null  object
# dtypes: category(2), datetime64[ns](1), int32(1), int64(1), object(6)
# memory usage: 15.0+ MB

# %%
df.sample(5)
# Out:
#         show_id     type                               title  \
# 101424     4343    Movie                         Line Walker
# 90791      3822  TV Show        Dennis and Gnasher Unleashed
# 174314     7666    Movie                     One Night Stand
# 200694     8766    Movie                                  XX
# 23269       936    Movie  Madagascar 3: Europe's Most Wanted
#
#                 director                 cast         country date_added  \
# 101424         Jazz Boon         Louis Cheung       Hong Kong 2018-12-01
# 90791   Unknown_director  Kelly Marie Stewart  United Kingdom 2019-05-15
# 174314   Jasmine D'Souza   Madhurima Banerjee           India 2017-10-15
# 200694  Jovanka Vuckovic      Jonathan Watton          Canada 2017-06-22
# 23269      Conrad Vernon      David Schwimmer   United States 2021-05-01
#
#         release_year      rating  duration             listed_in
# 101424          2016      Adults   109 min    Action & Adventure
# ...

# %%
df = pd.DataFrame(df)

filename = 'df.csv'
df.to_csv(filename, index=False)

files.download(filename)
print(f"DataFrame saved as '{df}' and ready for download.")
# Out:
# DataFrame saved as '        show_id     type                 title          director  \
# 0             1    Movie  Dick Johnson Is Dead   Kirsten Johnson
# 1             2  TV Show         Blood & Water  Unknown_director
# 2             2  TV Show         Blood & Water  Unknown_director
# 3             2  TV Show         Blood & Water  Unknown_director
# 4             2  TV Show         Blood & Water  Unknown_director
# ...         ...      ...                   ...               ...
# 201840     8807    Movie                Zubaan       Mozez Singh
# 201841     8807    Movie                Zubaan       Mozez Singh
# 201842     8807    Movie                Zubaan       Mozez Singh
# 201843     8807    Movie                Zubaan       Mozez Singh
# 201844     8807    Movie                Zubaan       Mozez Singh
#
#                          cast        country date_added  release_year  \
# 0                Unknown_cast  United States 2021-09-25          2020
# ...
